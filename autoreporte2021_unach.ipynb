# %% [markdown]
# <a href="https://colab.research.google.com/github/jsilvacode/colab/blob/main/autoreporte2021_unach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# acceso desde Colab a Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# importando librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df es el objeto donde se carga el documento indicado en la ruta, utilizando el método 'read_csv'. Se indica tipo de separador y codificación para caracteres especiales
df = pd.read_csv('/content/drive/MyDrive/CAAE/autoreporte_df.csv', sep = ";", encoding = "ISO-8859-1")

# %%
df.head()

# %%
# eliminamos las columnas innecesarias y se almacena el nuevo set de datos en el dataframe 'unach'
unach = df.drop(['id', 'telefono', 'email'], axis=1)

# %%
unach.head()
# Out:
#           rut                   nombres  ... estudia_obligado            diagnóstico
# 0  20779068-0           Alexandra Sofia  ...               No              No Aplica
# 1  17187762-8  Viviana De Las Mercedes   ...               No  Vasculitis Autoinmune
# 2   212726826            Daniel Vicente  ...               No              No Aplica
# 3  21259502-0           Carlos Fernando  ...               No              No Aplica
# 4  20373142-6            Catalina Belén  ...               No   Depresión y ansiedad
#
# [5 rows x 38 columns]
